# %%
import os, sys
sys.path.append('../lib')

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from srgan import SRGAN

# %%
from utils import image_split, image_combine

# %%
srgan = SRGAN((28,28,3))

# %%
srgan.load_train_image('../data/train_set_temp/')

# %%
srgan.split_train_image()

# %%
srgan.train_generator(epochs=1, batch_size=128)
# Out:
# Train on 1909 samples, validate on 278 samples
# Epoch 1/1
# 1909/1909 [==============================] - 238s 124ms/step - loss: 0.1147 - mean_squared_error: 0.1147 - psnr: 10.3068 - val_loss: 0.0802 - val_mean_squared_error: 0.0802 - val_psnr: 10.9720

# %%
out = srgan.generator.predict(srgan.lr_valid_split[:66])

# %%
tmp = [np.concatenate(out[i*11:(i+1)*1], axis=1) for i in range(6)]
res = np.concatenate(tmp, axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-70f41d6ab6a3> in <module>
# ----> 1 tmp = [np.concatenate(out[i*11:(i+1)*1], axis=1) for i in range(6)]
#       2 res = np.concatenate(tmp, axis=0)
#
# <ipython-input-17-70f41d6ab6a3> in <listcomp>(.0)
# ----> 1 tmp = [np.concatenate(out[i*11:(i+1)*1], axis=1) for i in range(6)]
#       2 res = np.concatenate(tmp, axis=0)
#
# ValueError: need at least one array to concatenate

# %%
plt.imshow(np.squeeze(out.reshape(-1,336,616,3),axis=0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
srgan.train_dims[0]
# Out:
# (6, 11)

# %%
lr_img = load_image('../data/train_set_temp/LR')
hr_img = load_image('../data/train_set_temp/HR')

# %%
lr_train, hr_train, lr_valid, hr_valid = train_valid_split(lr_img, hr_img)

# %%
a = [image_split(img,28,28) for img in lr_train]
b = [image_split(img,56,56) for img in hr_train]

# %%
k = [(i[0], i[1]) for i in a]

# %%
x, y = [],[]
for i in range(len(a)):
    x.extend(a[i][2])
    y.extend(b[i][2])

# %%
x = np.concatenate(np.expand_dims(x, axis=0),axis=0)
y = np.concatenate(np.expand_dims(y, axis=0),axis=0)

# %%
a = image_split(lr_train[0],28,28)

# %%
b = image_split(hr_train[0], 56, 56)

# %%
b = image_combine(a[2], a[0], a[1])

# %%
srgan = SRGAN((28,28,3))

# %%
aa.shape

# %%
plt.imshow(aa[100])

# %%
srgan.train_generator(epochs=1, batch_size=1, validation=True)

# %%
srgan.train_gan(epochs=4, batch_size=16, validation=True)

# %%
out = srgan.generator.predict(srgan.train_lr_image)

# %%
out.shape

# %%
plt.imshow(srgan.train_lr_image[1])

# %%
plt.imshow(np.squeeze(out[1]))
